# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(666)
x = np.random.uniform(-3.0, 3.0, size=100)
X = x.reshape(-1, 1)
y = 0.5 * x**2 + x + 2 + np.random.normal(0, 1, size=100)

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### 使用线性回归

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.score(X, y)
# Out:
# 0.4953707811865009

# %%
y_predict = lin_reg.predict(X)
plt.scatter(x, y)
plt.plot(np.sort(x), y_predict[np.argsort(x)], color = 'r')
plt.show()

# %%
from sklearn.metrics import mean_squared_error

y_predict = lin_reg.predict(X)
mean_squared_error(y, y_predict)  # 对同一组数据，使用不同的方法进行拟合，得到的均方误差具有可比性
# Out:
# 3.0750025765636577

# %% [markdown]
# ### 使用多项式回归

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

def PolynomialRegression(degree):
    return Pipeline([
        ("poly", PolynomialFeatures(degree=degree)),
        ("std_scaler", StandardScaler()),
        ("lin_reg", LinearRegression())
    ])

# %%
poly2_reg = PolynomialRegression(degree=2)
poly2_reg.fit(X, y)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures()),
#                 ('std_scaler', StandardScaler()),
#                 ('lin_reg', LinearRegression())])

# %%
y2_predict = poly2_reg.predict(X)
mean_squared_error(y, y2_predict)
# Out:
# 1.0987392142417856

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y2_predict[np.argsort(x)], color='r')
plt.show()

# %%
# 提高degree
poly10_reg = PolynomialRegression(degree=10)
poly10_reg.fit(X, y)

y10_predict = poly10_reg.predict(X)
mean_squared_error(y, y10_predict)  # 均方误差降低了
# Out:
# 1.0508466763764148

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y10_predict[np.argsort(x)], color='r')
plt.show()  # 图像变得复杂了点

# %%
poly100_reg = PolynomialRegression(degree=100) # 再度提高degree
poly100_reg.fit(X, y)

y100_predict = poly100_reg.predict(X)
mean_squared_error(y, y100_predict) # 均方误差继续降低
# Out:
# 0.6879768981520811

# %%
plt.scatter(x, y)
plt.plot(np.sort(x), y100_predict[np.argsort(x)], color='r')
plt.show()

# %%
# 研究上述图像
X_plot = np.linspace(-3, 3, 100).reshape(100, 1)
y_plot = poly100_reg.predict(X_plot)

plt.scatter(x, y)
plt.plot(X_plot[:,0], y_plot, color='r')
plt.axis([-3, 3, 0, 10])  # x轴显示范围[-3,3],y轴显示范围[0,10]
plt.show()

# %%
# 可以发现，随着degree的提高，模型变得越来越复杂。虽然均方误差再降低。
# 这就是过拟合
# 而以直线拟合数据，会出现欠拟合
