# %% [markdown]
# ### L1正则和L2正则
#
# ![image.png](attachment:image.png)
# 对此再进行下泛化：
# ![image-2.png](attachment:image-2.png)
# 于是：
# ![image-3.png](attachment:image-3.png)
#
# ### L0正则
#
# ![image-4.png](attachment:image-4.png)
# 因为L1正则可以做特征选择，故可以用L1取代。
#
# ### 弹性网
#
# ![image-5.png](attachment:image-5.png)
# 结合了L1正则和L2正则，同时具有二者的优势。
#
# ### 选择原则
#
# 1. 优先选择岭回归。因为它的计算是精准的。它的缺点是如果特征数量特别大的话，由于它不具有特征选择的功能，导致计算量特别大
# 2. 此时应该优先选择弹性网
# 3. LASSO缺点在于急于将某些特征化为0，导致某些特征可能被消除。导致最终的模型误差比较大。
