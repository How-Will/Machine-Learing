# %% [markdown]
# ### 主成分分析
#
# - 一个非监督的机器学习算法
# - 主要用于数据的降维
# - 通过降维，可以发现更便于人类理解的特征
# - 其他应用：可视化；去噪
#
# 1. 如下的样本点，要进行降维。我们可以将其映射到x轴，或y轴。但是这两种映射方式，样本点之间的距离并不是最大的。样本间距最大的映射方式如下:
# ![image-13.png](attachment:image-13.png)
# ![image.png](attachment:image.png)
#
# 2. 如何定义样本间的间距？使用方差（描述样本间分布整体疏密的指标。方差越大，分布越稀疏。越小，越紧密）
# ![image-2.png](attachment:image-2.png)
#
# 3. 主成分分析的第一步：将样例的均值归为0（demean）。即每一个样本点减均值。相当与移动了坐标轴
# ![image-5.png](attachment:image-5.png)
# 4. 总结
# ![image-6.png](attachment:image-6.png)
# 虽然映射到了（w1,w2）这条轴上，但该轴还是位于一个二维空间。故X还是一个向量，故应该是模的运算：
# ![image-14.png](attachment:image-14.png)
# 又因为进行了demean处理，Xbar = 0,故
# ![image-9.png](attachment:image-9.png)
#
# 如何取得最大值？
# ![image-8.png](attachment:image-8.png)
# 又w是方向向量，取单位向量即可.故如下化简：
# ![image-10.png](attachment:image-10.png)
# 又可进行如下化简：
# ![image-11.png](attachment:image-11.png)
# 故目标转化成：
# ![image-15.png](attachment:image-15.png)
# 于是可以用梯度上升法来求解

# %% [markdown]
# ### 和线性回归的区别
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
