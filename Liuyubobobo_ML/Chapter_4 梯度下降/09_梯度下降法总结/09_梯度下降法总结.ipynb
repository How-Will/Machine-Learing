# %% [markdown]
# ### 总结
#
# - 批量梯度下降法
# 缺点：每次都要对所有的样本看一遍，才能求出梯度。导致速度比较慢
# 优点：稳定，每次都能像梯度下降的方向前进
#
# - 随机梯度下降法
# 缺点：不稳定，每次下降的方向不确定，甚至可能向反方向前进
# 优点：每次只需要看一个样本，就能求出梯度。速度比较快
#
# - 小批量梯度下降法
# 每次都看k个样本。兼顾了批量梯度下降法和随机梯度下降法的优点。
#
# - 梯度上升法
# ![image.png](attachment:image.png)
