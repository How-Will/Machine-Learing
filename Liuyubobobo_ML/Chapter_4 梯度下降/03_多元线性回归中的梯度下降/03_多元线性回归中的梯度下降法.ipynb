# %% [markdown]
# ### 多元线性回归的梯度下降
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# 可以发现，对于式子中的每一项都和m有关，即和样本数量相关。这是不合理的。因该让梯度中每一项都和m无关。于是转换成：
# ![image-5.png](attachment:image-5.png)
