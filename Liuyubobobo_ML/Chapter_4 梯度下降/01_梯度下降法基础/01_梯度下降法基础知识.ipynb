# %% [markdown]
# ### 梯度下降法
#
# - 不是一个机器学习算法，是一种基于搜索的最优化方法。
# - 作用：最小化一个损失函数。而最大化一个效用函数的话，使用梯度上升法。
#
# ![image.png](attachment:image.png)
#
# 因为我们需要找的是极小值点，故对导数取-，即对应J减小的方向。
# η是学习率，是一个超参数，它的取值影响获得最优解的速度，取值不合适的话，甚至得不到最优解。**η太大，可能导致不收敛，η太小，减慢收敛速度。**
#
# 并不是所有函数都有唯一的极值点。
# ![image-3.png](attachment:image-3.png)
# 解决方案：
#    - 多次运行，随机化初始点。**（可见，初始点也是一个超参数）**
#    - 梯度下降法的初始点也是一个超参数
