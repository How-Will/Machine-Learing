# %% [markdown]
# ### SVM解决回归问题
#
# 回归问题的本质：找到一根直线，最佳程度拟合数据点。怎么定义拟合是不同回归算法的关键。
# SVM定义拟合为：在Margin的范围内，包含的数据点越多越好。越多，代表这个margin范围能更好地表达数据点。
# ![image.png](attachment:image.png)
# 超参数ε：对Margin的范围进行指定

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

boston = datasets.load_boston()
X = boston.data
y = boston.target

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

# %%
from sklearn.svm import LinearSVR # 使用线性SVM来处理回归问题
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

def StandardScalerSVR(epsilon=0.1):
    return Pipeline([
        ('std_scaler', StandardScaler()),
        ('linearSVR', LinearSVR(epsilon=epsilon))
    ])

# %%
svr = StandardScalerSVR()
svr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('std_scaler', StandardScaler()),
#                 ('linearSVR', LinearSVR(epsilon=0.1))])

# %%
svr.score(X_test, y_test)
# Out:
# 0.6356824672081836
