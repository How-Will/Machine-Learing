# %% [markdown]
# ### SVM
#
# 对于决策边界不唯一的问题，称为不适定问题
# ![image.png](attachment:image.png)
# 逻辑回归解决该问题的思路是：定义一个概率函数，sigmoid。根据概率函数进行建模，形成了损失函数。通过最小化损失函数，来求出决策边界。
# SVM解决问题的方法是：找到一条决策边界，该边界离我们的分类样本尽量的远。即离决策边界最近的那些点，到决策边界的距离尽可能的远。
# ![image-3.png](attachment:image-3.png)
# 解决线性可分问题：Hard Margin SVM
# 解决线性不可分问题：Soft Margin SVM
