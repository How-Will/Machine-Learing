# %% [markdown]
# ### Soft Margin SVM
#
# 原理是对Hard Margin SVM的限定条件加以宽松，让数据点不一定在Margin的外头，给限定条件加一个宽松量：
# ![image.png](attachment:image.png)
#
# η不是固定的值，而是对于每一个样本数据都有一个相应的η与其对应。即对于每个数据点都求出它对应的容错空间。
# η不能趋于正无穷，此时容错范围太大。解决方法是加上一项η的和。
# ![image-2.png](attachment:image-2.png)
# 应该对式子中的两部分的重要程度比，做些修改：
# ![image-3.png](attachment:image-3.png)
# C特别大时，优化目标就是后半部分，容错空间越小。反之，优化前半部分，容错空间越大。
# ![image-4.png](attachment:image-4.png)
